# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sohin'

# %%
import os
os.listdir()
# Out:
# ['$PROFILE.txt',
#  '.anaconda',
#  '.android',
#  '.bash_history',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.firebase',
#  '.firebaserc',
#  '.gitignore',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.packettracer',
#  '.spyder-py3',
#  '.VirtualBox',
#  '.vscode',
#  '3D Objects',
#  '=4',
#  'anaconda3',
#  'anaconda_projects',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'automatedfilesorter.ipynb',
#  'BEAUTIFUL SOUP AND REQUEST.ipynb',
#  'bmi_calc.ipynb',
#  'Cisco Packet Tracer 9.0.0',
#  'Contacts',
#  'Cookies',
#  'cpp',
#  'datascraping.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'findandfind_all.ipynb',
#  'firebase.json',
#  'functions',
#  'IdeaProjects',
#  'index.js',
#  'IntelGraphicsProfiles',
#  'javascript',
#  'javascript1',
#  'lab1.ipynb',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'node_modules',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a8861774-ee2a-11ef-a985-d68cfc744880}.TM.blf',
#  'NTUSER.DAT{a8861774-ee2a-11ef-a985-d68cfc744880}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{a8861774-ee2a-11ef-a985-d68cfc744880}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy1.ipynb',
#  'numpy2.ipynb',
#  'numpy3.ipynb',
#  'numpy4.ipynb',
#  'OneDrive',
#  'package-lock.json',
#  'package.json',
#  'PrintHood',
#  'projects',
#  'public',
#  'PycharmProjects',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'showcase-craft-10',
#  'SONAR.ipynb',
#  'SONAR_MODEL.sav',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Videos']

# %%
import pickle

loaded_model = pickle.load(open("SONAR_MODEL.sav", "rb"))

# %%
import numpy as np

# %%
input_data = (0.02,0.0371,0.0428,0.0207,0.0954,0.0986,0.1539,0.1601,0.3109,0.2111,
0.1609,0.1582,0.2238,0.0645,0.0660,0.2273,0.3100,0.2999,0.5078,0.4797,
0.5783,0.5071,0.4328,0.5550,0.6711,0.6415,0.7104,0.8080,0.6791,0.3857,
0.1307,0.2604,0.5121,0.7547,0.8537,0.8507,0.6692,0.6097,0.4943,0.2744,
0.0510,0.2834,0.2825,0.4256,0.2641,0.1386,0.1051,0.1343,0.0383,0.0324,
0.0232,0.0027,0.0065,0.0159,0.0072,0.0167,0.0180,0.0084,0.0090,0.0032)
input_array = np.asarray(input_data)
input_reshaped = input_array.reshape(1,-1)
prediction = loaded_model.predict(input_reshaped)
print(prediction)
if prediction[0] == 'R':
    print("The object is a Rock")
else:
    print("The object is a Mine")
# Out:
# ['R']
# The object is a Rock
